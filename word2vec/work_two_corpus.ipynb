# %%
import pickle
with open("/workspaces/master_thesis/results/word2vec/snomed_corpus_lemmat", "rb") as fp:   # Unpickling
  snomed_corpus = pickle.load(fp)

# %%
snomed_corpus
# Out:
# [['radiate', 'chest', 'pain'],
#  ['urine', 'tryptophancreatinine', 'ratio'],
#  ['nuhope',
#   'belt',
#   'leave',
#   'small',
#   'c',
#   'cmcm',
#   'length',
#   'width',
#   'opening',
#   'nuhope',
#   'laboratories',
#   'inc',
#   'device'],
#  ['urine', 'threoninecreatinine', 'ratio'],
#  ['nuhope',
#   'belt',
#   'right',
#   'large',
#   'cmcm',
#   'length',
#   'width',
#   'opening',
#   'nuhope',
#   'laboratories',
#   'inc'],
#  ['urine', 'taurinecreatinine', 'ratio'],
#  ['nuhope',
#   'belt',
#   'leave',
#   'small',
#   'dc',
#   'cmcm',
#   'length',
#   'width',
#   'opening',
#   'nuhope',
#   'laboratories',
#   'inc'],
#  ['urine', 'phenylalaninecreatinine', 'ratio'],
#  ['nuhope',
#   'belt',
#   'leave',
#   'small',
#   'dc',
#   'cmcm',
#   'length',
#   'width',
#   'opening',
#   'nuhope',
#   'laboratories',
#   'inc',
#   'device'],
#  ['urine', 'ornithinecreatinine', 'ratio'],
#  ['nuhope',
#   'belt',
#   'right',
#   'large',
#   'cmcm',
# ...

# %%
import wiki as w

# %%
WIKIXML = 'data/{lang}wiki-latest-pages-articles-multistream.xml.bz2'

# %%
wiki_sentences = w.WikiSentences(WIKIXML.format(lang='en'), 'en') #164minutes

# %%
len(list(wiki_sentences))
# Out:
# WARNING:gensim.corpora.wikicorpus:user terminated iteration over Wikipedia corpus after 553871 documents with 715140972 positions (total 1191630 articles, 717808661 positions before pruning articles shorter than 50 words)
# 553871

# %%
import pickle

# %%
with open("wiki_corpus", "wb") as fp:   #Pickling
  pickle.dump(list(wiki_sentences), fp)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pickle

# %%
with open("pubmed_corpus", "rb") as fp:   # Unpickling
  b = pickle.load(fp)

# %%
len(b)
# Out:
# 186077

# %%
with open("/workspaces/master_thesis/results/word2vec/wiki_corpus", "rb") as fp:   # Unpickling
  b = pickle.load(fp)

# %%
list(b)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2100440/67367400.py in <module>
# ----> 1 list(b)
#
# /workspaces/master_thesis/wiki.py in __iter__(self)
#      38
#      39     def __iter__(self):
# ---> 40         for sentence in self.wiki.get_texts():
#      41             yield list(sentence)
#
# /opt/conda/lib/python3.9/site-packages/gensim/corpora/wikicorpus.py in get_texts(self)
#     683             (text, title, pageid, tokenization_params)
#     684             for title, text, pageid
# --> 685             in extract_pages(bz2.BZ2File(self.fname), self.filter_namespaces, self.filter_articles)
#     686         )
#     687         pool = multiprocessing.Pool(self.processes, init_to_ignore_interrupt)
#
# /opt/conda/lib/python3.9/bz2.py in __init__(self, filename, mode, compresslevel)
#      83
# ...

# %%
#
dsf

wiki_corpus + snomed_corpus_lemmat
from gensim.models import Word2Vec
model = Word2Vec(all_text, min_count=5, vector_size= 100, workers=3, window=3, sg = 0)
model.train(all_text, total_examples=model.corpus_count, epochs=50)
