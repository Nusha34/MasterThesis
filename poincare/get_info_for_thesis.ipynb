# %%
import pandas as pd

# %%
#load cocnepts
concepts=pd.read_csv('/workspaces/master_thesis/CONCEPT.csv', on_bad_lines='skip', sep='\t')
# Out:
# /tmp/ipykernel_2411657/933074145.py:2: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   concepts=pd.read_csv('/workspaces/master_thesis/CONCEPT.csv', on_bad_lines='skip', sep='\t')

# %%
#filter by standard_concept
concepts=concepts[concepts.standard_concept=='S']

# %%
concepts
# Out:
#          concept_id                              concept_name domain_id
# 0           1146945                        concept.concept_id  Metadata  \
# 1           1146954                    concept.invalid_reason  Metadata
# 2           1147044  observation_period.observation_period_id  Metadata
# 3            756315         metadata.metadata_type_concept_id  Metadata
# 4            756316                             metadata.name  Metadata
# ...             ...                                       ...       ...
# 1242677       32761          Person Under Investigation (PUI)     Visit
# 1242678       33004               Supplier / Service Provider     Visit
# 1242679       33007                 Alternate care site (ACS)     Visit
# 1242680        9202                          Outpatient Visit     Visit
# 1242681      705159              Ambulatory long COVID clinic     Visit
#
#         vocabulary_id concept_class_id standard_concept concept_code
# ...

# %%
from build_graph import Builder

# %%
#build graph
from build_graph import Builder

# %%
build = Builder('/workspaces/master_thesis/CONCEPT_RELATIONSHIP.csv', '/workspaces/master_thesis/CONCEPT.csv')
# Out:
# /workspaces/master_thesis/poincare/build_graph.py:11: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data_concept = pd.read_csv(path_concept, on_bad_lines='skip', sep='\t')

# %%
df=build.get_dataframe()
# Out:
# /workspaces/master_thesis/poincare/build_graph.py:41: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_merge_2=data_merge_2[data_merge_2.standard_concept_x=='S'][data_merge_2.standard_concept_y=='S']

# %%
df
# Out:
#          concept_id_1                                     concept_name_x
# 0                 281                              Medicare Managed Care  \
# 1                 282     Medicare Health Maintenance Organization (HMO)
# 2                 283     Medicare Preferred Provider Organization (PPO)
# 3                 284                    Medicare Point of Service (POS)
# 4                 285                          Medicare Non-managed Care
# ...               ...                                                ...
# 1695762       3661632  Thrombocytopenia due to Severe acute respirato...
# 1695763       3655975  Sepsis due to disease caused by Severe acute r...
# 1695764       3661748  Acute kidney injury due to disease caused by S...
# 1695765       3655976  Acute hypoxemic respiratory failure due to dis...
# 1695766       3655977  Rhabdomyolysis due to disease caused by Severe...
#
#          concept_id_2         concept_name_y relationship_id
# ...

# %%
#get some random records from dataframe
df.sample(10)
# Out:
#          concept_id_1                                     concept_name_x
# 835696       41995762                                      Ariano Irpino  \
# 80953         4035539          Electrophoresis method with 8.9 pH buffer
# 96001         4047176                Herpes simplex virus identification
# 842995       42003061                                          Racconigi
# 4907           192669                                    Gastric fistula
# 1078707      45993375  MC2000 ileostomy bag 5955 55mm Clear (Coloplas...
# 965339       44798465  Registered general nurse - Royal Army Nursing ...
# 187053        4119636                                    No hip movement
# 1101542      46003385  Fulcionel female high waist support briefs wit...
# 1636355      46279268  Sigvaris Essential Thermoregulating class 2 (2...
#
#          concept_id_2                               concept_name_y
# 835696       41987280                                     Avellino  \
# ...

# %%
#calculate number of nodes and edges 
print('Number of nodes: ', len(df.concept_id_1.unique()))
print('Number of edges: ', len(df))
# Out:
# Number of nodes:  745104
# Number of edges:  1111803
