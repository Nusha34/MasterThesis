# %%
import gensim

# %%
from gensim.models import KeyedVectors
from gensim import models
from gensim.models import Word2Vec

# %%
model = Word2Vec.load("/workspaces/master_thesis/word2vec_snomed_wiki.model")

# %%
len(model.wv)
# Out:
# 1711306

# %%
model.wv.similarity('chest', 'pain')
# Out:
# 0.4173246

# %%
model.wv.similarity('chest', 'level')
# Out:
# 0.06141012

# %%
model.wv.most_similar('chest')
# Out:
# [('forehead', 0.7362309694290161),
#  ('neck', 0.6953780651092529),
#  ('thigh', 0.6696295738220215),
#  ('throat', 0.6641250848770142),
#  ('stomach', 0.6596812009811401),
#  ('shoulder', 0.6573643684387207),
#  ('torso', 0.6442036628723145),
#  ('abdomen', 0.6344805955886841),
#  ('ribcage', 0.6333176493644714),
#  ('armpit', 0.6329252123832703)]

# %%
model.wv.evaluate_word_analogies('/workspaces/master_thesis/files_for_evaluation/questions-words.txt')
# Out:
# (0.6953999383920321,
#  [{'section': 'capital-common-countries',
#    'correct': [('ATHENS', 'GREECE', 'BANGKOK', 'THAILAND'),
#     ('ATHENS', 'GREECE', 'BEIJING', 'CHINA'),
#     ('ATHENS', 'GREECE', 'BERLIN', 'GERMANY'),
#     ('ATHENS', 'GREECE', 'BERN', 'SWITZERLAND'),
#     ('ATHENS', 'GREECE', 'CAIRO', 'EGYPT'),
#     ('ATHENS', 'GREECE', 'CANBERRA', 'AUSTRALIA'),
#     ('ATHENS', 'GREECE', 'HAVANA', 'CUBA'),
#     ('ATHENS', 'GREECE', 'HELSINKI', 'FINLAND'),
#     ('ATHENS', 'GREECE', 'ISLAMABAD', 'PAKISTAN'),
#     ('ATHENS', 'GREECE', 'KABUL', 'AFGHANISTAN'),
#     ('ATHENS', 'GREECE', 'LONDON', 'ENGLAND'),
#     ('ATHENS', 'GREECE', 'MADRID', 'SPAIN'),
#     ('ATHENS', 'GREECE', 'MOSCOW', 'RUSSIA'),
#     ('ATHENS', 'GREECE', 'OSLO', 'NORWAY'),
#     ('ATHENS', 'GREECE', 'OTTAWA', 'CANADA'),
#     ('ATHENS', 'GREECE', 'PARIS', 'FRANCE'),
#     ('ATHENS', 'GREECE', 'ROME', 'ITALY'),
#     ('ATHENS', 'GREECE', 'STOCKHOLM', 'SWEDEN'),
# ...

# %%
model.wv.evaluate_word_analogies('/workspaces/master_thesis/files_for_evaluation/analogy_questions_umls.txt')
# Out:
# (0.01763967357187696,
#  [{'section': 'UMLS_causative',
#    'correct': [('SEPSIS', 'MICROORGANISM', 'LISTERIOSIS', 'LISTERIA'),
#     ('TRYPANOSOMIASIS', 'TRYPANOSOMA', 'BABESIOSIS', 'BABESIA'),
#     ('ONYCHOMYCOSIS', 'FUNGI', 'LEISHMANIASIS', 'PROTOZOA'),
#     ('TRYPANOSOMIASIS', 'TRYPANOSOMA', 'GIARDIASIS', 'GIARDIA'),
#     ('TRYPANOSOMIASIS', 'TRYPANOSOMA', 'LISTERIOSIS', 'LISTERIA'),
#     ('SCHISTOSOMIASIS', 'SCHISTOSOMA', 'LISTERIOSIS', 'LISTERIA'),
#     ('POLIOMYELITIS', 'ENTEROVIRUS', 'LISTERIOSIS', 'LISTERIA'),
#     ('TYPHUS', 'RICKETTSIA', 'BABESIOSIS', 'BABESIA'),
#     ('SUBMERSION', 'WATER', 'ASBESTOSIS', 'ASBESTOS')],
#    'incorrect': [('MANGE', 'MITES', 'ASBESTOSIS', 'ASBESTOS'),
#     ('POLIOMYELITIS', 'ENTEROVIRUS', 'OSTEOMYELITIS', 'ORGANISM'),
#     ('PNEUMOCONIOSIS', 'DUST', 'MANGE', 'MITES'),
#     ('PYELONEPHRITIS', 'ORGANISM', 'LEISHMANIASIS', 'PROTOZOA'),
#     ('OSTEOMYELITIS', 'ORGANISM', 'ONYCHOMYCOSIS', 'FUNGI'),
# ...
